# %%
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
model_1=pd.read_csv('model_1.csv')
model_2=pd.read_csv('model_2.csv')
model_3=pd.read_csv('model_3.csv')
model_4=pd.read_csv('model_4.csv')
model_5=pd.read_csv('model_5.csv')
model_6=pd.read_csv('model_6.csv')
model_7=pd.read_csv('model_7.csv')
model_8=pd.read_csv('model_8.csv')
model_9=pd.read_csv('model_9.csv')
model_10=pd.read_csv('model_10.csv')

# %%
model_3.head()
# Out:
#    epoch      loss  output_1_accuracy  output_1_loss  output_2_accuracy  \
# 0      0  0.455301           0.888299       0.261178           0.926402
# 1      1  0.259587           0.920690       0.190268           0.975026
# 2      2  0.214801           0.931711       0.168874           0.984228
# 3      3  0.188660           0.941263       0.151520           0.987492
# 4      4  0.168650           0.948716       0.136994           0.989416
#
#    output_2_loss  val_loss  val_output_1_accuracy  val_output_1_loss  \
# 0       0.194124  0.277658               0.911309           0.211565
# 1       0.069319  0.236574               0.921582           0.190414
# 2       0.045928  0.232025               0.929685           0.176723
# 3       0.037140  0.165531               0.947653           0.137568
# 4       0.031656  0.174872               0.961802           0.113057
#
#    val_output_2_accuracy  val_output_2_loss
# 0               0.982718           0.066093
# ...

# %%
plt.rcParams["figure.figsize"] = [14, 8]
plt.grid()
font1 = {'family':'serif','color':'black','size':15}
font2 = {'family':'serif','color':'black','size':15}
plt.plot(model_1['epoch'], model_1['loss'], color = 'blue',label='model_1_loss')
plt.plot(model_2['epoch'], model_2['loss'], color = 'red',label='model_2_loss')
plt.plot(model_3['epoch'], model_3['loss'], color = 'orange',label='model_3_loss')
plt.plot(model_4['epoch'], model_4['loss'], color = 'brown',label='model_4_loss')
plt.plot(model_5['epoch'], model_5['loss'], color = 'yellow',label='model_5_loss')
plt.plot(model_6['epoch'], model_6['loss'], color = 'green',label='model_6_loss')
plt.plot(model_7['epoch'], model_7['loss'], color = 'purple',label='model_7_loss')
plt.plot(model_8['epoch'], model_8['loss'], color = 'black',label='model_8_loss')
plt.xlabel('Epochs',fontdict = font2)
plt.ylabel('Loss',fontdict = font2)
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [14, 8]
plt.grid()
font1 = {'family':'serif','color':'black','size':15}
font2 = {'family':'serif','color':'black','size':15}
plt.plot(model_1['epoch'], model_1['val_output_1_accuracy'], color = 'blue',label='model_1_val_DoH_Filtering_accuracy')
plt.plot(model_2['epoch'], model_2['val_output_1_accuracy'], color = 'red',label='model_2_val_DoH_Filtering_accuracy')
plt.plot(model_3['epoch'], model_3['val_output_1_accuracy'], color = 'orange',label='model_3_val_DoH_Filtering_accuracy')
plt.plot(model_4['epoch'], model_4['val_output_1_accuracy'], color = 'brown',label='model_4_val_DoH_Filtering_accuracy')
plt.plot(model_5['epoch'], model_5['val_output_1_accuracy'], color = 'yellow',label='model_5_val_DoH_Filtering_accuracy')
plt.plot(model_6['epoch'], model_6['val_output_1_accuracy'], color = 'green',label='model_6_val_DoH_Filtering_accuracy')
plt.plot(model_7['epoch'], model_7['val_output_1_accuracy'], color = 'purple',label='model_7_val_DoH_Filtering_accuracy')
plt.plot(model_8['epoch'], model_8['val_output_1_accuracy'], color = 'black',label='model_8_val_DoH_Filtering_accuracy')
plt.plot(model_9['epoch'], model_9['val_output_1_accuracy'], color = 'black',label='model_9_val_DoH_Filtering_accuracy')
plt.xlabel('Epochs',fontdict = font2)
plt.ylabel('Loss',fontdict = font2)
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [14, 8]
plt.grid()
font1 = {'family':'serif','color':'black','size':15}
font2 = {'family':'serif','color':'black','size':15}

plt.plot(model_1['epoch'], model_1['output_1_loss'], color = 'blue',label='model_1_DoH_Filtering_loss')
plt.plot(model_2['epoch'], model_2['output_1_loss'], color = 'red',label='model_2_DoH_Filtering_loss')
plt.plot(model_3['epoch'], model_3['output_1_loss'], color = 'orange',label='model_3_DoH_Filtering_loss')
plt.plot(model_4['epoch'], model_4['output_1_loss'], color = 'brown',label='model_4_DoH_Filtering_loss')
plt.plot(model_5['epoch'], model_5['output_1_loss'], color = 'yellow',label='model_5_DoH_Filtering_loss')
plt.plot(model_6['epoch'], model_6['output_1_loss'], color = 'green',label='model_6_DoH_Filtering_loss')
plt.plot(model_7['epoch'], model_7['output_1_loss'], color = 'purple',label='model_7_DoH_Filtering_loss')
plt.plot(model_8['epoch'], model_8['output_1_loss'], color = 'black',label='model_8_DoH_Filtering_loss')
plt.plot(model_9['epoch'], model_9['output_1_loss'], color = 'darkred',label='model_9_DoH_Filtering_loss')
plt.plot(model_10['epoch'], model_10['output_1_loss'], color = 'cyan',label='model_10_DoH_Filtering_loss')
plt.xlabel('Epochs',fontdict = font2)
plt.ylabel('Loss',fontdict = font2)
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [14, 8]
plt.grid()
font1 = {'family':'serif','color':'black','size':15}
font2 = {'family':'serif','color':'black','size':15}
plt.plot(model_1['epoch'], model_1['output_2_loss'], color = 'c',label='model_1_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_2['epoch'], model_2['output_2_loss'], color = 'm',label='model_2_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_3['epoch'], model_3['output_2_loss'], color = 'navy',label='model_3_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_4['epoch'], model_4['output_2_loss'], color = 'indigo',label='model_4_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_5['epoch'], model_5['output_2_loss'], color = 'aqua',label='model_5_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_6['epoch'], model_6['output_2_loss'], color = 'teal',label='model_6_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_7['epoch'], model_7['output_2_loss'], color = 'lime',label='model_7_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_8['epoch'], model_8['output_2_loss'], color = 'gold',label='model_8_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_9['epoch'], model_9['output_2_loss'], color = 'darkred',label='model_9_Bengin_and_Malicious_Filtering_loss')
plt.plot(model_10['epoch'], model_10['output_2_loss'], color = 'blue',label='model_10_Bengin_and_Malicious_Filtering_loss')
plt.xlabel('Epochs',fontdict = font2)
plt.ylabel('Loss',fontdict = font2)
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [14, 8]
plt.grid()
font1 = {'family':'serif','color':'black','size':15}
font2 = {'family':'serif','color':'black','size':15}
plt.plot(model_1['epoch'], model_1['output_1_accuracy'], color = 'blue',label='model_1_DoH_Filtering_accuracy')
plt.plot(model_2['epoch'], model_2['output_1_accuracy'], color = 'red',label='model_2_DoH_Filtering_accuracy')
plt.plot(model_3['epoch'], model_3['output_1_accuracy'], color = 'orange',label='model_3_DoH_Filtering_accuracy')
plt.plot(model_4['epoch'], model_4['output_1_accuracy'], color = 'brown',label='model_4_DoH_Filtering_accuracy')
plt.plot(model_5['epoch'], model_5['output_1_accuracy'], color = 'yellow',label='model_5_DoH_Filtering_accuracy')
plt.plot(model_6['epoch'], model_6['output_1_accuracy'], color = 'green',label='model_6_DoH_Filtering_accuracy')
plt.plot(model_7['epoch'], model_7['output_1_accuracy'], color = 'purple',label='model_7_DoH_Filtering_accuracy')
plt.plot(model_8['epoch'], model_8['output_1_accuracy'], color = 'black',label='model_8_DoH_Filtering_accuracy')
plt.plot(model_9['epoch'], model_9['output_1_accuracy'], color = 'darkred',label='model_9_DoH_Filtering_accuracy')
plt.plot(model_10['epoch'], model_10['output_1_accuracy'], color = 'cyan',label='model_10_DoH_Filtering_accuracy')
plt.xlabel('Epochs',fontdict = font2)
plt.ylabel('Accuracy',fontdict = font2)
plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [14, 8]
plt.grid()
font1 = {'family':'serif','color':'black','size':15}
font2 = {'family':'serif','color':'black','size':15}
plt.plot(model_1['epoch'], model_1['output_2_accuracy'], color = 'c',label='model_1_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_2['epoch'], model_2['output_2_accuracy'], color = 'm',label='model_2_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_3['epoch'], model_3['output_2_accuracy'], color = 'navy',label='model_3_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_4['epoch'], model_4['output_2_accuracy'], color = 'indigo',label='model_4_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_5['epoch'], model_5['output_2_accuracy'], color = 'aqua',label='model_5_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_6['epoch'], model_6['output_2_accuracy'], color = 'teal',label='model_6_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_7['epoch'], model_7['output_2_accuracy'], color = 'lime',label='model_7_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_8['epoch'], model_8['output_2_accuracy'], color = 'gold',label='model_8_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_9['epoch'], model_9['output_2_accuracy'], color = 'darkred',label='model_9_Bengin_and_Malicious_Filtering_accuracy')
plt.plot(model_10['epoch'], model_10['output_2_accuracy'], color = 'blue',label='model_10_Bengin_and_Malicious_Filtering_accuracy')
plt.xlabel('Epochs',fontdict = font2)
plt.ylabel('Accuracy',fontdict = font2)
plt.legend()
plt.show()
